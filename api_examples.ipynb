# %% [markdown]
# # Примеры использования API справочника организаций
#
# Этот ноутбук демонстрирует примеры работы с API через библиотеку requests.

# %%
import requests
import json
from pprint import pprint
from dotenv import load_dotenv
import os

# Загружаем переменные окружения из .env
load_dotenv()

# Базовый URL API
BASE_URL = "http://localhost:8000/api/v1"

# API ключ из .env
API_KEY = os.getenv("API_KEY")

# Заголовки для запросов
headers = {
    "X-API-Key": API_KEY
}

# %% [markdown]
# ## 1. Получение списка организаций

# %%
# Получение всех организаций
response = requests.get(f"{BASE_URL}/organizations", headers=headers)
print(f"Статус: {response.status_code}")
pprint(response.json())
# Out:
# Статус: 200
# [{'activities': [{'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None},
#                  {'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1}],
#   'building': {'address': '123 Main St, Downtown',
#                'id': 1,
#                'latitude': 55.7558,
#                'longitude': 37.6173},
#   'building_id': 1,
#   'id': 1,
#   'name': 'ТехноМаркет',
#   'phones': [{'phone': '+74951112233'}, {'phone': '+74951112234'}]},
#  {'activities': [{'id': 12, 'level': 2, 'name': 'Кафе', 'parent_id': 2},
#                  {'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None}],
#   'building': {'address': '123 Main St, Downtown',
#                'id': 1,
#                'latitude': 55.7558,
#                'longitude': 37.6173},
#   'building_id': 1,
#   'id': 2,
#   'name': 'Кафе "У Парка"',
#   'phones': [{'phone': '+74952223344'}, {'phone': '+74952223345'}]},
#  {'activities': [{'id': 13,
#                   'level': 2,
#                   'name': 'Медицинские центры',
#                   'parent_id': 3},
#                  {'id': 3,
#                   'level': 1,
#                   'name': 'Здравоохранение',
#                   'parent_id': None}],
#   'building': {'address': '456 Oak Ave, West Side',
#                'id': 2,
#                'latitude': 55.7517,
#                'longitude': 37.6178},
#   'building_id': 2,
#   'id': 3,
#   'name': 'Медицинский центр "Здоровье"',
#   'phones': [{'phone': '+74953334455'}, {'phone': '+74953334456'}]},
#  {'activities': [{'id': 8, 'level': 2, 'name': 'Разработка ПО', 'parent_id': 4},
#                  {'id': 4, 'level': 1, 'name': 'Технологии', 'parent_id': None},
#                  {'id': 14,
#                   'level': 2,
#                   'name': 'IT-консалтинг',
#                   'parent_id': 4}],
#   'building': {'address': '456 Oak Ave, West Side',
#                'id': 2,
#                'latitude': 55.7517,
#                'longitude': 37.6178},
#   'building_id': 2,
#   'id': 4,
#   'name': 'IT Solutions',
#   'phones': [{'phone': '+74954445566'}, {'phone': '+74954445567'}]},
#  {'activities': [{'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None},
#                  {'id': 15,
#                   'level': 3,
#                   'name': 'Бытовая техника',
#                   'parent_id': 5},
#                  {'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1}],
#   'building': {'address': '789 Pine Rd, East End',
#                'id': 3,
#                'latitude': 55.7547,
#                'longitude': 37.6163},
#   'building_id': 3,
#   'id': 5,
#   'name': 'Электроника и К',
#   'phones': [{'phone': '+74955556677'}, {'phone': '+74955556678'}]},
#  {'activities': [{'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None},
#                  {'id': 6, 'level': 2, 'name': 'Рестораны', 'parent_id': 2}],
#   'building': {'address': '789 Pine Rd, East End',
#                'id': 3,
#                'latitude': 55.7547,
#                'longitude': 37.6163},
#   'building_id': 3,
#   'id': 6,
#   'name': 'Ресторан "Панорама"',
#   'phones': [{'phone': '+74956667788'}, {'phone': '+74956667789'}]},
#  {'activities': [{'id': 7, 'level': 2, 'name': 'Аптеки', 'parent_id': 3},
#                  {'id': 3,
#                   'level': 1,
#                   'name': 'Здравоохранение',
#                   'parent_id': None}],
#   'building': {'address': '321 Elm St, North District',
#                'id': 4,
#                'latitude': 55.7538,
#                'longitude': 37.6168},
#   'building_id': 4,
#   'id': 7,
#   'name': 'Аптека 36.6',
#   'phones': [{'phone': '+74957778899'}, {'phone': '+74957778890'}]},
#  {'activities': [{'id': 4, 'level': 1, 'name': 'Технологии', 'parent_id': None},
#                  {'id': 8,
#                   'level': 2,
#                   'name': 'Разработка ПО',
#                   'parent_id': 4}],
#   'building': {'address': '321 Elm St, North District',
#                'id': 4,
#                'latitude': 55.7538,
#                'longitude': 37.6168},
#   'building_id': 4,
#   'id': 8,
#   'name': 'Софт-Девелопмент',
#   'phones': [{'phone': '+74958889900'}, {'phone': '+74958889901'}]},
#  {'activities': [{'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None},
#                  {'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5}],
#   'building': {'address': '654 Maple Dr, South Area',
#                'id': 5,
#                'latitude': 55.7528,
#                'longitude': 37.6183},
#   'building_id': 5,
#   'id': 9,
#   'name': 'МобиШоп',
#   'phones': [{'phone': '+74959990011'}, {'phone': '+74959990012'}]},
#  {'activities': [{'id': 10, 'level': 3, 'name': 'Фастфуд', 'parent_id': 6},
#                  {'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None}],
#   'building': {'address': '654 Maple Dr, South Area',
#                'id': 5,
#                'latitude': 55.7528,
#                'longitude': 37.6183},
#   'building_id': 5,
#   'id': 10,
#   'name': 'Фастфуд "Экспресс"',
#   'phones': [{'phone': '+74950001122'}, {'phone': '+74950001123'}]},
#  {'activities': [{'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None},
#                  {'id': 11,
#                   'level': 2,
#                   'name': 'Продуктовые магазины',
#                   'parent_id': 1}],
#   'building': {'address': '987 Cedar Ln, Central',
#                'id': 6,
#                'latitude': 55.7568,
#                'longitude': 37.6153},
#   'building_id': 6,
#   'id': 11,
#   'name': 'Продукты 24/7',
#   'phones': [{'phone': '+74951113344'}, {'phone': '+74951113345'}]},
#  {'activities': [{'id': 12, 'level': 2, 'name': 'Кафе', 'parent_id': 2},
#                  {'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None}],
#   'building': {'address': '987 Cedar Ln, Central',
#                'id': 6,
#                'latitude': 55.7568,
#                'longitude': 37.6153},
#   'building_id': 6,
#   'id': 12,
#   'name': 'Кофейня "Утро"',
#   'phones': [{'phone': '+74952224455'}, {'phone': '+74952224456'}]},
#  {'activities': [{'id': 13,
#                   'level': 2,
#                   'name': 'Медицинские центры',
#                   'parent_id': 3},
#                  {'id': 3,
#                   'level': 1,
#                   'name': 'Здравоохранение',
#                   'parent_id': None}],
#   'building': {'address': '147 Birch Rd, Heights',
#                'id': 7,
#                'latitude': 55.7578,
#                'longitude': 37.6143},
#   'building_id': 7,
#   'id': 13,
#   'name': 'Клиника "Добрый доктор"',
#   'phones': [{'phone': '+74953335566'}, {'phone': '+74953335567'}]},
#  {'activities': [{'id': 14,
#                   'level': 2,
#                   'name': 'IT-консалтинг',
#                   'parent_id': 4},
#                  {'id': 4,
#                   'level': 1,
#                   'name': 'Технологии',
#                   'parent_id': None}],
#   'building': {'address': '147 Birch Rd, Heights',
#                'id': 7,
#                'latitude': 55.7578,
#                'longitude': 37.6143},
#   'building_id': 7,
#   'id': 14,
#   'name': 'ИТ-Консультант',
#   'phones': [{'phone': '+74954446677'}, {'phone': '+74954446678'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 15,
#                   'level': 3,
#                   'name': 'Бытовая техника',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '258 Spruce Ave, Valley',
#                'id': 8,
#                'latitude': 55.7588,
#                'longitude': 37.6133},
#   'building_id': 8,
#   'id': 15,
#   'name': 'Техно-Сервис',
#   'phones': [{'phone': '+74955557788'}, {'phone': '+74955557789'}]},
#  {'activities': [{'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None},
#                  {'id': 6, 'level': 2, 'name': 'Рестораны', 'parent_id': 2}],
#   'building': {'address': '258 Spruce Ave, Valley',
#                'id': 8,
#                'latitude': 55.7588,
#                'longitude': 37.6133},
#   'building_id': 8,
#   'id': 16,
#   'name': 'Ресторан "Веранда"',
#   'phones': [{'phone': '+74956668899'}, {'phone': '+74956668890'}]},
#  {'activities': [{'id': 7, 'level': 2, 'name': 'Аптеки', 'parent_id': 3},
#                  {'id': 3,
#                   'level': 1,
#                   'name': 'Здравоохранение',
#                   'parent_id': None}],
#   'building': {'address': '369 Ash St, Plaza',
#                'id': 9,
#                'latitude': 55.7598,
#                'longitude': 37.6123},
#   'building_id': 9,
#   'id': 17,
#   'name': 'Аптека "Здоровье+"',
#   'phones': [{'phone': '+74957779900'}, {'phone': '+74957779901'}]},
#  {'activities': [{'id': 4, 'level': 1, 'name': 'Технологии', 'parent_id': None},
#                  {'id': 8,
#                   'level': 2,
#                   'name': 'Разработка ПО',
#                   'parent_id': 4}],
#   'building': {'address': '369 Ash St, Plaza',
#                'id': 9,
#                'latitude': 55.7598,
#                'longitude': 37.6123},
#   'building_id': 9,
#   'id': 18,
#   'name': 'Разработка.Про',
#   'phones': [{'phone': '+74958880011'}, {'phone': '+74958880012'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '741 Willow Dr, Park',
#                'id': 10,
#                'latitude': 55.7508,
#                'longitude': 37.6193},
#   'building_id': 10,
#   'id': 19,
#   'name': 'Смартфон-Маркет',
#   'phones': [{'phone': '+74959991122'}, {'phone': '+74959991123'}]},
#  {'activities': [{'id': 10, 'level': 3, 'name': 'Фастфуд', 'parent_id': 6},
#                  {'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None}],
#   'building': {'address': '741 Willow Dr, Park',
#                'id': 10,
#                'latitude': 55.7508,
#                'longitude': 37.6193},
#   'building_id': 10,
#   'id': 20,
#   'name': 'Бургер-Хаус',
#   'phones': [{'phone': '+74950002233'}, {'phone': '+74950002234'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '123 Main St, Downtown',
#                'id': 1,
#                'latitude': 55.7558,
#                'longitude': 37.6173},
#   'building_id': 1,
#   'id': 21,
#   'name': 'Цифровой Мир',
#   'phones': [{'phone': '+74951112244'}, {'phone': '+74951112245'}]},
#  {'activities': [{'id': 12, 'level': 2, 'name': 'Кафе', 'parent_id': 2},
#                  {'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None}],
#   'building': {'address': '456 Oak Ave, West Side',
#                'id': 2,
#                'latitude': 55.7517,
#                'longitude': 37.6178},
#   'building_id': 2,
#   'id': 22,
#   'name': 'Суши-бар "Сакура"',
#   'phones': [{'phone': '+74952223355'}, {'phone': '+74952223356'}]},
#  {'activities': [{'id': 13,
#                   'level': 2,
#                   'name': 'Медицинские центры',
#                   'parent_id': 3},
#                  {'id': 3,
#                   'level': 1,
#                   'name': 'Здравоохранение',
#                   'parent_id': None}],
#   'building': {'address': '789 Pine Rd, East End',
#                'id': 3,
#                'latitude': 55.7547,
#                'longitude': 37.6163},
#   'building_id': 3,
#   'id': 23,
#   'name': 'Стоматология "Улыбка"',
#   'phones': [{'phone': '+74953334466'}, {'phone': '+74953334467'}]},
#  {'activities': [{'id': 14,
#                   'level': 2,
#                   'name': 'IT-консалтинг',
#                   'parent_id': 4},
#                  {'id': 4, 'level': 1, 'name': 'Технологии', 'parent_id': None},
#                  {'id': 8,
#                   'level': 2,
#                   'name': 'Разработка ПО',
#                   'parent_id': 4}],
#   'building': {'address': '321 Elm St, North District',
#                'id': 4,
#                'latitude': 55.7538,
#                'longitude': 37.6168},
#   'building_id': 4,
#   'id': 24,
#   'name': 'Web Studio',
#   'phones': [{'phone': '+74954445577'}, {'phone': '+74954445578'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 15,
#                   'level': 3,
#                   'name': 'Бытовая техника',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '654 Maple Dr, South Area',
#                'id': 5,
#                'latitude': 55.7528,
#                'longitude': 37.6183},
#   'building_id': 5,
#   'id': 25,
#   'name': 'Гаджет-Маркет',
#   'phones': [{'phone': '+74955556688'}, {'phone': '+74955556689'}]},
#  {'activities': [{'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None},
#                  {'id': 6, 'level': 2, 'name': 'Рестораны', 'parent_id': 2}],
#   'building': {'address': '987 Cedar Ln, Central',
#                'id': 6,
#                'latitude': 55.7568,
#                'longitude': 37.6153},
#   'building_id': 6,
#   'id': 26,
#   'name': 'Пиццерия "Италия"',
#   'phones': [{'phone': '+74956667799'}, {'phone': '+74956667800'}]},
#  {'activities': [{'id': 7, 'level': 2, 'name': 'Аптеки', 'parent_id': 3},
#                  {'id': 3,
#                   'level': 1,
#                   'name': 'Здравоохранение',
#                   'parent_id': None}],
#   'building': {'address': '147 Birch Rd, Heights',
#                'id': 7,
#                'latitude': 55.7578,
#                'longitude': 37.6143},
#   'building_id': 7,
#   'id': 27,
#   'name': 'Оптика "Взгляд"',
#   'phones': [{'phone': '+74957778800'}, {'phone': '+74957778801'}]},
#  {'activities': [{'id': 4, 'level': 1, 'name': 'Технологии', 'parent_id': None},
#                  {'id': 8,
#                   'level': 2,
#                   'name': 'Разработка ПО',
#                   'parent_id': 4}],
#   'building': {'address': '258 Spruce Ave, Valley',
#                'id': 8,
#                'latitude': 55.7588,
#                'longitude': 37.6133},
#   'building_id': 8,
#   'id': 28,
#   'name': 'Digital Agency',
#   'phones': [{'phone': '+74958889911'}, {'phone': '+74958889912'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '369 Ash St, Plaza',
#                'id': 9,
#                'latitude': 55.7598,
#                'longitude': 37.6123},
#   'building_id': 9,
#   'id': 29,
#   'name': 'Электроника-Сервис',
#   'phones': [{'phone': '+74959990022'}, {'phone': '+74959990023'}]},
#  {'activities': [{'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None},
#                  {'id': 10, 'level': 3, 'name': 'Фастфуд', 'parent_id': 6}],
#   'building': {'address': '741 Willow Dr, Park',
#                'id': 10,
#                'latitude': 55.7508,
#                'longitude': 37.6193},
#   'building_id': 10,
#   'id': 30,
#   'name': 'Столовая "Домашняя"',
#   'phones': [{'phone': '+74950001133'}, {'phone': '+74950001134'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None},
#                  {'id': 15,
#                   'level': 3,
#                   'name': 'Бытовая техника',
#                   'parent_id': 5}],
#   'building': {'address': '852 Cherry Ln, Square',
#                'id': 11,
#                'latitude': 55.7518,
#                'longitude': 37.6113},
#   'building_id': 11,
#   'id': 31,
#   'name': 'Компьютерный магазин',
#   'phones': [{'phone': '+74951113355'}, {'phone': '+74951113356'}]},
#  {'activities': [{'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None},
#                  {'id': 12, 'level': 2, 'name': 'Кафе', 'parent_id': 2}],
#   'building': {'address': '852 Cherry Ln, Square',
#                'id': 11,
#                'latitude': 55.7518,
#                'longitude': 37.6113},
#   'building_id': 11,
#   'id': 32,
#   'name': 'Чайная "Восток"',
#   'phones': [{'phone': '+74952224466'}, {'phone': '+74952224467'}]},
#  {'activities': [{'id': 13,
#                   'level': 2,
#                   'name': 'Медицинские центры',
#                   'parent_id': 3},
#                  {'id': 3,
#                   'level': 1,
#                   'name': 'Здравоохранение',
#                   'parent_id': None}],
#   'building': {'address': '963 Poplar Rd, Gardens',
#                'id': 12,
#                'latitude': 55.7528,
#                'longitude': 37.6103},
#   'building_id': 12,
#   'id': 33,
#   'name': 'Медпункт "Айболит"',
#   'phones': [{'phone': '+74953335577'}, {'phone': '+74953335578'}]},
#  {'activities': [{'id': 14,
#                   'level': 2,
#                   'name': 'IT-консалтинг',
#                   'parent_id': 4},
#                  {'id': 4, 'level': 1, 'name': 'Технологии', 'parent_id': None},
#                  {'id': 8,
#                   'level': 2,
#                   'name': 'Разработка ПО',
#                   'parent_id': 4}],
#   'building': {'address': '963 Poplar Rd, Gardens',
#                'id': 12,
#                'latitude': 55.7528,
#                'longitude': 37.6103},
#   'building_id': 12,
#   'id': 34,
#   'name': 'Software House',
#   'phones': [{'phone': '+74954446688'}, {'phone': '+74954446689'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '159 Cypress Ave, Hills',
#                'id': 13,
#                'latitude': 55.7538,
#                'longitude': 37.6093},
#   'building_id': 13,
#   'id': 35,
#   'name': 'Мир Связи',
#   'phones': [{'phone': '+74955557799'}, {'phone': '+74955557800'}]},
#  {'activities': [{'id': 12, 'level': 2, 'name': 'Кафе', 'parent_id': 2},
#                  {'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None}],
#   'building': {'address': '159 Cypress Ave, Hills',
#                'id': 13,
#                'latitude': 55.7538,
#                'longitude': 37.6093},
#   'building_id': 13,
#   'id': 36,
#   'name': 'Кафе "Прага"',
#   'phones': [{'phone': '+74956668800'}, {'phone': '+74956668801'}]},
#  {'activities': [{'id': 3,
#                   'level': 1,
#                   'name': 'Здравоохранение',
#                   'parent_id': None},
#                  {'id': 13,
#                   'level': 2,
#                   'name': 'Медицинские центры',
#                   'parent_id': 3}],
#   'building': {'address': '357 Magnolia St, Lake',
#                'id': 14,
#                'latitude': 55.7548,
#                'longitude': 37.6083},
#   'building_id': 14,
#   'id': 37,
#   'name': 'Клиника "Вита"',
#   'phones': [{'phone': '+74957779911'}, {'phone': '+74957779912'}]},
#  {'activities': [{'id': 4, 'level': 1, 'name': 'Технологии', 'parent_id': None},
#                  {'id': 8,
#                   'level': 2,
#                   'name': 'Разработка ПО',
#                   'parent_id': 4}],
#   'building': {'address': '357 Magnolia St, Lake',
#                'id': 14,
#                'latitude': 55.7548,
#                'longitude': 37.6083},
#   'building_id': 14,
#   'id': 38,
#   'name': 'Tech Support',
#   'phones': [{'phone': '+74958880022'}, {'phone': '+74958880023'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 15,
#                   'level': 3,
#                   'name': 'Бытовая техника',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '486 Juniper Dr, Ridge',
#                'id': 15,
#                'latitude': 55.7558,
#                'longitude': 37.6073},
#   'building_id': 15,
#   'id': 39,
#   'name': 'Техно-Центр',
#   'phones': [{'phone': '+74959991133'}, {'phone': '+74959991134'}]},
#  {'activities': [{'id': 6, 'level': 2, 'name': 'Рестораны', 'parent_id': 2},
#                  {'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None}],
#   'building': {'address': '486 Juniper Dr, Ridge',
#                'id': 15,
#                'latitude': 55.7558,
#                'longitude': 37.6073},
#   'building_id': 15,
#   'id': 40,
#   'name': 'Ресторан "Метрополь"',
#   'phones': [{'phone': '+74950002244'}, {'phone': '+74950002245'}]},
#  {'activities': [{'id': 7, 'level': 2, 'name': 'Аптеки', 'parent_id': 3},
#                  {'id': 3,
#                   'level': 1,
#                   'name': 'Здравоохранение',
#                   'parent_id': None}],
#   'building': {'address': '792 Sycamore Ln, View',
#                'id': 16,
#                'latitude': 55.7568,
#                'longitude': 37.6063},
#   'building_id': 16,
#   'id': 41,
#   'name': 'Аптека "Первая"',
#   'phones': [{'phone': '+74951114466'}, {'phone': '+74951114467'}]},
#  {'activities': [{'id': 4, 'level': 1, 'name': 'Технологии', 'parent_id': None},
#                  {'id': 8,
#                   'level': 2,
#                   'name': 'Разработка ПО',
#                   'parent_id': 4}],
#   'building': {'address': '792 Sycamore Ln, View',
#                'id': 16,
#                'latitude': 55.7568,
#                'longitude': 37.6063},
#   'building_id': 16,
#   'id': 42,
#   'name': 'Code Factory',
#   'phones': [{'phone': '+74952225577'}, {'phone': '+74952225578'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '148 Acacia Rd, Summit',
#                'id': 17,
#                'latitude': 55.7578,
#                'longitude': 37.6053},
#   'building_id': 17,
#   'id': 43,
#   'name': 'Смарт-Шоп',
#   'phones': [{'phone': '+74953336688'}, {'phone': '+74953336689'}]},
#  {'activities': [{'id': 10, 'level': 3, 'name': 'Фастфуд', 'parent_id': 6},
#                  {'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None}],
#   'building': {'address': '148 Acacia Rd, Summit',
#                'id': 17,
#                'latitude': 55.7578,
#                'longitude': 37.6053},
#   'building_id': 17,
#   'id': 44,
#   'name': 'Бистро "Экспресс"',
#   'phones': [{'phone': '+74954447799'}, {'phone': '+74954447800'}]},
#  {'activities': [{'id': 13,
#                   'level': 2,
#                   'name': 'Медицинские центры',
#                   'parent_id': 3},
#                  {'id': 3,
#                   'level': 1,
#                   'name': 'Здравоохранение',
#                   'parent_id': None}],
#   'building': {'address': '259 Palm Ave, Harbor',
#                'id': 18,
#                'latitude': 55.7588,
#                'longitude': 37.6043},
#   'building_id': 18,
#   'id': 45,
#   'name': 'Медцентр "Забота"',
#   'phones': [{'phone': '+74955558800'}, {'phone': '+74955558801'}]},
#  {'activities': [{'id': 14,
#                   'level': 2,
#                   'name': 'IT-консалтинг',
#                   'parent_id': 4},
#                  {'id': 4, 'level': 1, 'name': 'Технологии', 'parent_id': None},
#                  {'id': 8,
#                   'level': 2,
#                   'name': 'Разработка ПО',
#                   'parent_id': 4}],
#   'building': {'address': '259 Palm Ave, Harbor',
#                'id': 18,
#                'latitude': 55.7588,
#                'longitude': 37.6043},
#   'building_id': 18,
#   'id': 46,
#   'name': 'DevOps Labs',
#   'phones': [{'phone': '+74956669911'}, {'phone': '+74956669912'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 15,
#                   'level': 3,
#                   'name': 'Бытовая техника',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '367 Redwood St, Beach',
#                'id': 19,
#                'latitude': 55.7598,
#                'longitude': 37.6033},
#   'building_id': 19,
#   'id': 47,
#   'name': 'Электро-Мир',
#   'phones': [{'phone': '+74957770022'}, {'phone': '+74957770023'}]},
#  {'activities': [{'id': 12, 'level': 2, 'name': 'Кафе', 'parent_id': 2},
#                  {'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None}],
#   'building': {'address': '367 Redwood St, Beach',
#                'id': 19,
#                'latitude': 55.7598,
#                'longitude': 37.6033},
#   'building_id': 19,
#   'id': 48,
#   'name': 'Кафе "Венеция"',
#   'phones': [{'phone': '+74958881133'}, {'phone': '+74958881134'}]},
#  {'activities': [{'id': 13,
#                   'level': 2,
#                   'name': 'Медицинские центры',
#                   'parent_id': 3},
#                  {'id': 3,
#                   'level': 1,
#                   'name': 'Здравоохранение',
#                   'parent_id': None}],
#   'building': {'address': '481 Sequoia Dr, Forest',
#                'id': 20,
#                'latitude': 55.7508,
#                'longitude': 37.6023},
#   'building_id': 20,
#   'id': 49,
#   'name': 'Поликлиника №1',
#   'phones': [{'phone': '+74959992244'}, {'phone': '+74959992245'}]},
#  {'activities': [{'id': 4, 'level': 1, 'name': 'Технологии', 'parent_id': None},
#                  {'id': 8,
#                   'level': 2,
#                   'name': 'Разработка ПО',
#                   'parent_id': 4}],
#   'building': {'address': '481 Sequoia Dr, Forest',
#                'id': 20,
#                'latitude': 55.7508,
#                'longitude': 37.6023},
#   'building_id': 20,
#   'id': 50,
#   'name': 'Data Systems',
#   'phones': [{'phone': '+74950003355'}, {'phone': '+74950003356'}]}]

# %% [markdown]
# ## 2. Поиск организаций по параметрам

# %%
# Поиск по названию
params = {"name": "Tech"}
response = requests.get(f"{BASE_URL}/organizations", headers=headers, params=params)
print(f"Поиск организаций с 'Tech' в названии:")
pprint(response.json())
# Out:
# Поиск организаций с 'Tech' в названии:
# [{'activities': [{'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None},
#                  {'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1}],
#   'building': {'address': '123 Main St, Downtown',
#                'id': 1,
#                'latitude': 55.7558,
#                'longitude': 37.6173},
#   'building_id': 1,
#   'id': 1,
#   'name': 'ТехноМаркет',
#   'phones': [{'phone': '+74951112233'}, {'phone': '+74951112234'}]},
#  {'activities': [{'id': 12, 'level': 2, 'name': 'Кафе', 'parent_id': 2},
#                  {'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None}],
#   'building': {'address': '123 Main St, Downtown',
#                'id': 1,
#                'latitude': 55.7558,
#                'longitude': 37.6173},
#   'building_id': 1,
#   'id': 2,
#   'name': 'Кафе "У Парка"',
#   'phones': [{'phone': '+74952223344'}, {'phone': '+74952223345'}]},
#  {'activities': [{'id': 13,
#                   'level': 2,
#                   'name': 'Медицинские центры',
#                   'parent_id': 3},
#                  {'id': 3,
#                   'level': 1,
#                   'name': 'Здравоохранение',
#                   'parent_id': None}],
#   'building': {'address': '456 Oak Ave, West Side',
#                'id': 2,
#                'latitude': 55.7517,
#                'longitude': 37.6178},
#   'building_id': 2,
#   'id': 3,
#   'name': 'Медицинский центр "Здоровье"',
#   'phones': [{'phone': '+74953334455'}, {'phone': '+74953334456'}]},
#  {'activities': [{'id': 8, 'level': 2, 'name': 'Разработка ПО', 'parent_id': 4},
#                  {'id': 4, 'level': 1, 'name': 'Технологии', 'parent_id': None},
#                  {'id': 14,
#                   'level': 2,
#                   'name': 'IT-консалтинг',
#                   'parent_id': 4}],
#   'building': {'address': '456 Oak Ave, West Side',
#                'id': 2,
#                'latitude': 55.7517,
#                'longitude': 37.6178},
#   'building_id': 2,
#   'id': 4,
#   'name': 'IT Solutions',
#   'phones': [{'phone': '+74954445566'}, {'phone': '+74954445567'}]},
#  {'activities': [{'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None},
#                  {'id': 15,
#                   'level': 3,
#                   'name': 'Бытовая техника',
#                   'parent_id': 5},
#                  {'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1}],
#   'building': {'address': '789 Pine Rd, East End',
#                'id': 3,
#                'latitude': 55.7547,
#                'longitude': 37.6163},
#   'building_id': 3,
#   'id': 5,
#   'name': 'Электроника и К',
#   'phones': [{'phone': '+74955556677'}, {'phone': '+74955556678'}]},
#  {'activities': [{'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None},
#                  {'id': 6, 'level': 2, 'name': 'Рестораны', 'parent_id': 2}],
#   'building': {'address': '789 Pine Rd, East End',
#                'id': 3,
#                'latitude': 55.7547,
#                'longitude': 37.6163},
#   'building_id': 3,
#   'id': 6,
#   'name': 'Ресторан "Панорама"',
#   'phones': [{'phone': '+74956667788'}, {'phone': '+74956667789'}]},
#  {'activities': [{'id': 7, 'level': 2, 'name': 'Аптеки', 'parent_id': 3},
#                  {'id': 3,
#                   'level': 1,
#                   'name': 'Здравоохранение',
#                   'parent_id': None}],
#   'building': {'address': '321 Elm St, North District',
#                'id': 4,
#                'latitude': 55.7538,
#                'longitude': 37.6168},
#   'building_id': 4,
#   'id': 7,
#   'name': 'Аптека 36.6',
#   'phones': [{'phone': '+74957778899'}, {'phone': '+74957778890'}]},
#  {'activities': [{'id': 4, 'level': 1, 'name': 'Технологии', 'parent_id': None},
#                  {'id': 8,
#                   'level': 2,
#                   'name': 'Разработка ПО',
#                   'parent_id': 4}],
#   'building': {'address': '321 Elm St, North District',
#                'id': 4,
#                'latitude': 55.7538,
#                'longitude': 37.6168},
#   'building_id': 4,
#   'id': 8,
#   'name': 'Софт-Девелопмент',
#   'phones': [{'phone': '+74958889900'}, {'phone': '+74958889901'}]},
#  {'activities': [{'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None},
#                  {'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5}],
#   'building': {'address': '654 Maple Dr, South Area',
#                'id': 5,
#                'latitude': 55.7528,
#                'longitude': 37.6183},
#   'building_id': 5,
#   'id': 9,
#   'name': 'МобиШоп',
#   'phones': [{'phone': '+74959990011'}, {'phone': '+74959990012'}]},
#  {'activities': [{'id': 10, 'level': 3, 'name': 'Фастфуд', 'parent_id': 6},
#                  {'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None}],
#   'building': {'address': '654 Maple Dr, South Area',
#                'id': 5,
#                'latitude': 55.7528,
#                'longitude': 37.6183},
#   'building_id': 5,
#   'id': 10,
#   'name': 'Фастфуд "Экспресс"',
#   'phones': [{'phone': '+74950001122'}, {'phone': '+74950001123'}]},
#  {'activities': [{'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None},
#                  {'id': 11,
#                   'level': 2,
#                   'name': 'Продуктовые магазины',
#                   'parent_id': 1}],
#   'building': {'address': '987 Cedar Ln, Central',
#                'id': 6,
#                'latitude': 55.7568,
#                'longitude': 37.6153},
#   'building_id': 6,
#   'id': 11,
#   'name': 'Продукты 24/7',
#   'phones': [{'phone': '+74951113344'}, {'phone': '+74951113345'}]},
#  {'activities': [{'id': 12, 'level': 2, 'name': 'Кафе', 'parent_id': 2},
#                  {'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None}],
#   'building': {'address': '987 Cedar Ln, Central',
#                'id': 6,
#                'latitude': 55.7568,
#                'longitude': 37.6153},
#   'building_id': 6,
#   'id': 12,
#   'name': 'Кофейня "Утро"',
#   'phones': [{'phone': '+74952224455'}, {'phone': '+74952224456'}]},
#  {'activities': [{'id': 13,
#                   'level': 2,
#                   'name': 'Медицинские центры',
#                   'parent_id': 3},
#                  {'id': 3,
#                   'level': 1,
#                   'name': 'Здравоохранение',
#                   'parent_id': None}],
#   'building': {'address': '147 Birch Rd, Heights',
#                'id': 7,
#                'latitude': 55.7578,
#                'longitude': 37.6143},
#   'building_id': 7,
#   'id': 13,
#   'name': 'Клиника "Добрый доктор"',
#   'phones': [{'phone': '+74953335566'}, {'phone': '+74953335567'}]},
#  {'activities': [{'id': 14,
#                   'level': 2,
#                   'name': 'IT-консалтинг',
#                   'parent_id': 4},
#                  {'id': 4,
#                   'level': 1,
#                   'name': 'Технологии',
#                   'parent_id': None}],
#   'building': {'address': '147 Birch Rd, Heights',
#                'id': 7,
#                'latitude': 55.7578,
#                'longitude': 37.6143},
#   'building_id': 7,
#   'id': 14,
#   'name': 'ИТ-Консультант',
#   'phones': [{'phone': '+74954446677'}, {'phone': '+74954446678'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 15,
#                   'level': 3,
#                   'name': 'Бытовая техника',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '258 Spruce Ave, Valley',
#                'id': 8,
#                'latitude': 55.7588,
#                'longitude': 37.6133},
#   'building_id': 8,
#   'id': 15,
#   'name': 'Техно-Сервис',
#   'phones': [{'phone': '+74955557788'}, {'phone': '+74955557789'}]},
#  {'activities': [{'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None},
#                  {'id': 6, 'level': 2, 'name': 'Рестораны', 'parent_id': 2}],
#   'building': {'address': '258 Spruce Ave, Valley',
#                'id': 8,
#                'latitude': 55.7588,
#                'longitude': 37.6133},
#   'building_id': 8,
#   'id': 16,
#   'name': 'Ресторан "Веранда"',
#   'phones': [{'phone': '+74956668899'}, {'phone': '+74956668890'}]},
#  {'activities': [{'id': 7, 'level': 2, 'name': 'Аптеки', 'parent_id': 3},
#                  {'id': 3,
#                   'level': 1,
#                   'name': 'Здравоохранение',
#                   'parent_id': None}],
#   'building': {'address': '369 Ash St, Plaza',
#                'id': 9,
#                'latitude': 55.7598,
#                'longitude': 37.6123},
#   'building_id': 9,
#   'id': 17,
#   'name': 'Аптека "Здоровье+"',
#   'phones': [{'phone': '+74957779900'}, {'phone': '+74957779901'}]},
#  {'activities': [{'id': 4, 'level': 1, 'name': 'Технологии', 'parent_id': None},
#                  {'id': 8,
#                   'level': 2,
#                   'name': 'Разработка ПО',
#                   'parent_id': 4}],
#   'building': {'address': '369 Ash St, Plaza',
#                'id': 9,
#                'latitude': 55.7598,
#                'longitude': 37.6123},
#   'building_id': 9,
#   'id': 18,
#   'name': 'Разработка.Про',
#   'phones': [{'phone': '+74958880011'}, {'phone': '+74958880012'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '741 Willow Dr, Park',
#                'id': 10,
#                'latitude': 55.7508,
#                'longitude': 37.6193},
#   'building_id': 10,
#   'id': 19,
#   'name': 'Смартфон-Маркет',
#   'phones': [{'phone': '+74959991122'}, {'phone': '+74959991123'}]},
#  {'activities': [{'id': 10, 'level': 3, 'name': 'Фастфуд', 'parent_id': 6},
#                  {'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None}],
#   'building': {'address': '741 Willow Dr, Park',
#                'id': 10,
#                'latitude': 55.7508,
#                'longitude': 37.6193},
#   'building_id': 10,
#   'id': 20,
#   'name': 'Бургер-Хаус',
#   'phones': [{'phone': '+74950002233'}, {'phone': '+74950002234'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '123 Main St, Downtown',
#                'id': 1,
#                'latitude': 55.7558,
#                'longitude': 37.6173},
#   'building_id': 1,
#   'id': 21,
#   'name': 'Цифровой Мир',
#   'phones': [{'phone': '+74951112244'}, {'phone': '+74951112245'}]},
#  {'activities': [{'id': 12, 'level': 2, 'name': 'Кафе', 'parent_id': 2},
#                  {'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None}],
#   'building': {'address': '456 Oak Ave, West Side',
#                'id': 2,
#                'latitude': 55.7517,
#                'longitude': 37.6178},
#   'building_id': 2,
#   'id': 22,
#   'name': 'Суши-бар "Сакура"',
#   'phones': [{'phone': '+74952223355'}, {'phone': '+74952223356'}]},
#  {'activities': [{'id': 13,
#                   'level': 2,
#                   'name': 'Медицинские центры',
#                   'parent_id': 3},
#                  {'id': 3,
#                   'level': 1,
#                   'name': 'Здравоохранение',
#                   'parent_id': None}],
#   'building': {'address': '789 Pine Rd, East End',
#                'id': 3,
#                'latitude': 55.7547,
#                'longitude': 37.6163},
#   'building_id': 3,
#   'id': 23,
#   'name': 'Стоматология "Улыбка"',
#   'phones': [{'phone': '+74953334466'}, {'phone': '+74953334467'}]},
#  {'activities': [{'id': 14,
#                   'level': 2,
#                   'name': 'IT-консалтинг',
#                   'parent_id': 4},
#                  {'id': 4, 'level': 1, 'name': 'Технологии', 'parent_id': None},
#                  {'id': 8,
#                   'level': 2,
#                   'name': 'Разработка ПО',
#                   'parent_id': 4}],
#   'building': {'address': '321 Elm St, North District',
#                'id': 4,
#                'latitude': 55.7538,
#                'longitude': 37.6168},
#   'building_id': 4,
#   'id': 24,
#   'name': 'Web Studio',
#   'phones': [{'phone': '+74954445577'}, {'phone': '+74954445578'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 15,
#                   'level': 3,
#                   'name': 'Бытовая техника',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '654 Maple Dr, South Area',
#                'id': 5,
#                'latitude': 55.7528,
#                'longitude': 37.6183},
#   'building_id': 5,
#   'id': 25,
#   'name': 'Гаджет-Маркет',
#   'phones': [{'phone': '+74955556688'}, {'phone': '+74955556689'}]},
#  {'activities': [{'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None},
#                  {'id': 6, 'level': 2, 'name': 'Рестораны', 'parent_id': 2}],
#   'building': {'address': '987 Cedar Ln, Central',
#                'id': 6,
#                'latitude': 55.7568,
#                'longitude': 37.6153},
#   'building_id': 6,
#   'id': 26,
#   'name': 'Пиццерия "Италия"',
#   'phones': [{'phone': '+74956667799'}, {'phone': '+74956667800'}]},
#  {'activities': [{'id': 7, 'level': 2, 'name': 'Аптеки', 'parent_id': 3},
#                  {'id': 3,
#                   'level': 1,
#                   'name': 'Здравоохранение',
#                   'parent_id': None}],
#   'building': {'address': '147 Birch Rd, Heights',
#                'id': 7,
#                'latitude': 55.7578,
#                'longitude': 37.6143},
#   'building_id': 7,
#   'id': 27,
#   'name': 'Оптика "Взгляд"',
#   'phones': [{'phone': '+74957778800'}, {'phone': '+74957778801'}]},
#  {'activities': [{'id': 4, 'level': 1, 'name': 'Технологии', 'parent_id': None},
#                  {'id': 8,
#                   'level': 2,
#                   'name': 'Разработка ПО',
#                   'parent_id': 4}],
#   'building': {'address': '258 Spruce Ave, Valley',
#                'id': 8,
#                'latitude': 55.7588,
#                'longitude': 37.6133},
#   'building_id': 8,
#   'id': 28,
#   'name': 'Digital Agency',
#   'phones': [{'phone': '+74958889911'}, {'phone': '+74958889912'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '369 Ash St, Plaza',
#                'id': 9,
#                'latitude': 55.7598,
#                'longitude': 37.6123},
#   'building_id': 9,
#   'id': 29,
#   'name': 'Электроника-Сервис',
#   'phones': [{'phone': '+74959990022'}, {'phone': '+74959990023'}]},
#  {'activities': [{'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None},
#                  {'id': 10, 'level': 3, 'name': 'Фастфуд', 'parent_id': 6}],
#   'building': {'address': '741 Willow Dr, Park',
#                'id': 10,
#                'latitude': 55.7508,
#                'longitude': 37.6193},
#   'building_id': 10,
#   'id': 30,
#   'name': 'Столовая "Домашняя"',
#   'phones': [{'phone': '+74950001133'}, {'phone': '+74950001134'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None},
#                  {'id': 15,
#                   'level': 3,
#                   'name': 'Бытовая техника',
#                   'parent_id': 5}],
#   'building': {'address': '852 Cherry Ln, Square',
#                'id': 11,
#                'latitude': 55.7518,
#                'longitude': 37.6113},
#   'building_id': 11,
#   'id': 31,
#   'name': 'Компьютерный магазин',
#   'phones': [{'phone': '+74951113355'}, {'phone': '+74951113356'}]},
#  {'activities': [{'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None},
#                  {'id': 12, 'level': 2, 'name': 'Кафе', 'parent_id': 2}],
#   'building': {'address': '852 Cherry Ln, Square',
#                'id': 11,
#                'latitude': 55.7518,
#                'longitude': 37.6113},
#   'building_id': 11,
#   'id': 32,
#   'name': 'Чайная "Восток"',
#   'phones': [{'phone': '+74952224466'}, {'phone': '+74952224467'}]},
#  {'activities': [{'id': 13,
#                   'level': 2,
#                   'name': 'Медицинские центры',
#                   'parent_id': 3},
#                  {'id': 3,
#                   'level': 1,
#                   'name': 'Здравоохранение',
#                   'parent_id': None}],
#   'building': {'address': '963 Poplar Rd, Gardens',
#                'id': 12,
#                'latitude': 55.7528,
#                'longitude': 37.6103},
#   'building_id': 12,
#   'id': 33,
#   'name': 'Медпункт "Айболит"',
#   'phones': [{'phone': '+74953335577'}, {'phone': '+74953335578'}]},
#  {'activities': [{'id': 14,
#                   'level': 2,
#                   'name': 'IT-консалтинг',
#                   'parent_id': 4},
#                  {'id': 4, 'level': 1, 'name': 'Технологии', 'parent_id': None},
#                  {'id': 8,
#                   'level': 2,
#                   'name': 'Разработка ПО',
#                   'parent_id': 4}],
#   'building': {'address': '963 Poplar Rd, Gardens',
#                'id': 12,
#                'latitude': 55.7528,
#                'longitude': 37.6103},
#   'building_id': 12,
#   'id': 34,
#   'name': 'Software House',
#   'phones': [{'phone': '+74954446688'}, {'phone': '+74954446689'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '159 Cypress Ave, Hills',
#                'id': 13,
#                'latitude': 55.7538,
#                'longitude': 37.6093},
#   'building_id': 13,
#   'id': 35,
#   'name': 'Мир Связи',
#   'phones': [{'phone': '+74955557799'}, {'phone': '+74955557800'}]},
#  {'activities': [{'id': 12, 'level': 2, 'name': 'Кафе', 'parent_id': 2},
#                  {'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None}],
#   'building': {'address': '159 Cypress Ave, Hills',
#                'id': 13,
#                'latitude': 55.7538,
#                'longitude': 37.6093},
#   'building_id': 13,
#   'id': 36,
#   'name': 'Кафе "Прага"',
#   'phones': [{'phone': '+74956668800'}, {'phone': '+74956668801'}]},
#  {'activities': [{'id': 3,
#                   'level': 1,
#                   'name': 'Здравоохранение',
#                   'parent_id': None},
#                  {'id': 13,
#                   'level': 2,
#                   'name': 'Медицинские центры',
#                   'parent_id': 3}],
#   'building': {'address': '357 Magnolia St, Lake',
#                'id': 14,
#                'latitude': 55.7548,
#                'longitude': 37.6083},
#   'building_id': 14,
#   'id': 37,
#   'name': 'Клиника "Вита"',
#   'phones': [{'phone': '+74957779911'}, {'phone': '+74957779912'}]},
#  {'activities': [{'id': 4, 'level': 1, 'name': 'Технологии', 'parent_id': None},
#                  {'id': 8,
#                   'level': 2,
#                   'name': 'Разработка ПО',
#                   'parent_id': 4}],
#   'building': {'address': '357 Magnolia St, Lake',
#                'id': 14,
#                'latitude': 55.7548,
#                'longitude': 37.6083},
#   'building_id': 14,
#   'id': 38,
#   'name': 'Tech Support',
#   'phones': [{'phone': '+74958880022'}, {'phone': '+74958880023'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 15,
#                   'level': 3,
#                   'name': 'Бытовая техника',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '486 Juniper Dr, Ridge',
#                'id': 15,
#                'latitude': 55.7558,
#                'longitude': 37.6073},
#   'building_id': 15,
#   'id': 39,
#   'name': 'Техно-Центр',
#   'phones': [{'phone': '+74959991133'}, {'phone': '+74959991134'}]},
#  {'activities': [{'id': 6, 'level': 2, 'name': 'Рестораны', 'parent_id': 2},
#                  {'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None}],
#   'building': {'address': '486 Juniper Dr, Ridge',
#                'id': 15,
#                'latitude': 55.7558,
#                'longitude': 37.6073},
#   'building_id': 15,
#   'id': 40,
#   'name': 'Ресторан "Метрополь"',
#   'phones': [{'phone': '+74950002244'}, {'phone': '+74950002245'}]},
#  {'activities': [{'id': 7, 'level': 2, 'name': 'Аптеки', 'parent_id': 3},
#                  {'id': 3,
#                   'level': 1,
#                   'name': 'Здравоохранение',
#                   'parent_id': None}],
#   'building': {'address': '792 Sycamore Ln, View',
#                'id': 16,
#                'latitude': 55.7568,
#                'longitude': 37.6063},
#   'building_id': 16,
#   'id': 41,
#   'name': 'Аптека "Первая"',
#   'phones': [{'phone': '+74951114466'}, {'phone': '+74951114467'}]},
#  {'activities': [{'id': 4, 'level': 1, 'name': 'Технологии', 'parent_id': None},
#                  {'id': 8,
#                   'level': 2,
#                   'name': 'Разработка ПО',
#                   'parent_id': 4}],
#   'building': {'address': '792 Sycamore Ln, View',
#                'id': 16,
#                'latitude': 55.7568,
#                'longitude': 37.6063},
#   'building_id': 16,
#   'id': 42,
#   'name': 'Code Factory',
#   'phones': [{'phone': '+74952225577'}, {'phone': '+74952225578'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '148 Acacia Rd, Summit',
#                'id': 17,
#                'latitude': 55.7578,
#                'longitude': 37.6053},
#   'building_id': 17,
#   'id': 43,
#   'name': 'Смарт-Шоп',
#   'phones': [{'phone': '+74953336688'}, {'phone': '+74953336689'}]},
#  {'activities': [{'id': 10, 'level': 3, 'name': 'Фастфуд', 'parent_id': 6},
#                  {'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None}],
#   'building': {'address': '148 Acacia Rd, Summit',
#                'id': 17,
#                'latitude': 55.7578,
#                'longitude': 37.6053},
#   'building_id': 17,
#   'id': 44,
#   'name': 'Бистро "Экспресс"',
#   'phones': [{'phone': '+74954447799'}, {'phone': '+74954447800'}]},
#  {'activities': [{'id': 13,
#                   'level': 2,
#                   'name': 'Медицинские центры',
#                   'parent_id': 3},
#                  {'id': 3,
#                   'level': 1,
#                   'name': 'Здравоохранение',
#                   'parent_id': None}],
#   'building': {'address': '259 Palm Ave, Harbor',
#                'id': 18,
#                'latitude': 55.7588,
#                'longitude': 37.6043},
#   'building_id': 18,
#   'id': 45,
#   'name': 'Медцентр "Забота"',
#   'phones': [{'phone': '+74955558800'}, {'phone': '+74955558801'}]},
#  {'activities': [{'id': 14,
#                   'level': 2,
#                   'name': 'IT-консалтинг',
#                   'parent_id': 4},
#                  {'id': 4, 'level': 1, 'name': 'Технологии', 'parent_id': None},
#                  {'id': 8,
#                   'level': 2,
#                   'name': 'Разработка ПО',
#                   'parent_id': 4}],
#   'building': {'address': '259 Palm Ave, Harbor',
#                'id': 18,
#                'latitude': 55.7588,
#                'longitude': 37.6043},
#   'building_id': 18,
#   'id': 46,
#   'name': 'DevOps Labs',
#   'phones': [{'phone': '+74956669911'}, {'phone': '+74956669912'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 15,
#                   'level': 3,
#                   'name': 'Бытовая техника',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '367 Redwood St, Beach',
#                'id': 19,
#                'latitude': 55.7598,
#                'longitude': 37.6033},
#   'building_id': 19,
#   'id': 47,
#   'name': 'Электро-Мир',
#   'phones': [{'phone': '+74957770022'}, {'phone': '+74957770023'}]},
#  {'activities': [{'id': 12, 'level': 2, 'name': 'Кафе', 'parent_id': 2},
#                  {'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None}],
#   'building': {'address': '367 Redwood St, Beach',
#                'id': 19,
#                'latitude': 55.7598,
#                'longitude': 37.6033},
#   'building_id': 19,
#   'id': 48,
#   'name': 'Кафе "Венеция"',
#   'phones': [{'phone': '+74958881133'}, {'phone': '+74958881134'}]},
#  {'activities': [{'id': 13,
#                   'level': 2,
#                   'name': 'Медицинские центры',
#                   'parent_id': 3},
#                  {'id': 3,
#                   'level': 1,
#                   'name': 'Здравоохранение',
#                   'parent_id': None}],
#   'building': {'address': '481 Sequoia Dr, Forest',
#                'id': 20,
#                'latitude': 55.7508,
#                'longitude': 37.6023},
#   'building_id': 20,
#   'id': 49,
#   'name': 'Поликлиника №1',
#   'phones': [{'phone': '+74959992244'}, {'phone': '+74959992245'}]},
#  {'activities': [{'id': 4, 'level': 1, 'name': 'Технологии', 'parent_id': None},
#                  {'id': 8,
#                   'level': 2,
#                   'name': 'Разработка ПО',
#                   'parent_id': 4}],
#   'building': {'address': '481 Sequoia Dr, Forest',
#                'id': 20,
#                'latitude': 55.7508,
#                'longitude': 37.6023},
#   'building_id': 20,
#   'id': 50,
#   'name': 'Data Systems',
#   'phones': [{'phone': '+74950003355'}, {'phone': '+74950003356'}]}]

# %%
# Поиск по id
org_id = 1
response = requests.get(f"{BASE_URL}/organizations/{org_id}", headers=headers)
print(f"Поиск организаций с id 1:")
pprint(response.json())
# Out:
# Поиск организаций с id 1:
# {'building_id': 1,
#  'id': 1,
#  'name': 'ТехноМаркет',
#  'phones': [{'phone': '+74951112233'}, {'phone': '+74951112234'}]}

# %%
# Поиск по радиусу
params = {
    "lat": 55.7558,
    "lon": 37.6173,
    "radius": 1.0
}
response = requests.get(f"{BASE_URL}/organizations", headers=headers, params=params)
print(f"Организации в радиусе 1 км от точки:")
pprint(response.json())
# Out:
# Организации в радиусе 1 км от точки:
# [{'activities': [{'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None},
#                  {'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1}],
#   'building': {'address': '123 Main St, Downtown',
#                'id': 1,
#                'latitude': 55.7558,
#                'longitude': 37.6173},
#   'building_id': 1,
#   'id': 1,
#   'name': 'ТехноМаркет',
#   'phones': [{'phone': '+74951112233'}, {'phone': '+74951112234'}]},
#  {'activities': [{'id': 12, 'level': 2, 'name': 'Кафе', 'parent_id': 2},
#                  {'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None}],
#   'building': {'address': '123 Main St, Downtown',
#                'id': 1,
#                'latitude': 55.7558,
#                'longitude': 37.6173},
#   'building_id': 1,
#   'id': 2,
#   'name': 'Кафе "У Парка"',
#   'phones': [{'phone': '+74952223344'}, {'phone': '+74952223345'}]},
#  {'activities': [{'id': 13,
#                   'level': 2,
#                   'name': 'Медицинские центры',
#                   'parent_id': 3},
#                  {'id': 3,
#                   'level': 1,
#                   'name': 'Здравоохранение',
#                   'parent_id': None}],
#   'building': {'address': '456 Oak Ave, West Side',
#                'id': 2,
#                'latitude': 55.7517,
#                'longitude': 37.6178},
#   'building_id': 2,
#   'id': 3,
#   'name': 'Медицинский центр "Здоровье"',
#   'phones': [{'phone': '+74953334455'}, {'phone': '+74953334456'}]},
#  {'activities': [{'id': 8, 'level': 2, 'name': 'Разработка ПО', 'parent_id': 4},
#                  {'id': 4, 'level': 1, 'name': 'Технологии', 'parent_id': None},
#                  {'id': 14,
#                   'level': 2,
#                   'name': 'IT-консалтинг',
#                   'parent_id': 4}],
#   'building': {'address': '456 Oak Ave, West Side',
#                'id': 2,
#                'latitude': 55.7517,
#                'longitude': 37.6178},
#   'building_id': 2,
#   'id': 4,
#   'name': 'IT Solutions',
#   'phones': [{'phone': '+74954445566'}, {'phone': '+74954445567'}]},
#  {'activities': [{'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None},
#                  {'id': 15,
#                   'level': 3,
#                   'name': 'Бытовая техника',
#                   'parent_id': 5},
#                  {'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1}],
#   'building': {'address': '789 Pine Rd, East End',
#                'id': 3,
#                'latitude': 55.7547,
#                'longitude': 37.6163},
#   'building_id': 3,
#   'id': 5,
#   'name': 'Электроника и К',
#   'phones': [{'phone': '+74955556677'}, {'phone': '+74955556678'}]},
#  {'activities': [{'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None},
#                  {'id': 6, 'level': 2, 'name': 'Рестораны', 'parent_id': 2}],
#   'building': {'address': '789 Pine Rd, East End',
#                'id': 3,
#                'latitude': 55.7547,
#                'longitude': 37.6163},
#   'building_id': 3,
#   'id': 6,
#   'name': 'Ресторан "Панорама"',
#   'phones': [{'phone': '+74956667788'}, {'phone': '+74956667789'}]},
#  {'activities': [{'id': 7, 'level': 2, 'name': 'Аптеки', 'parent_id': 3},
#                  {'id': 3,
#                   'level': 1,
#                   'name': 'Здравоохранение',
#                   'parent_id': None}],
#   'building': {'address': '321 Elm St, North District',
#                'id': 4,
#                'latitude': 55.7538,
#                'longitude': 37.6168},
#   'building_id': 4,
#   'id': 7,
#   'name': 'Аптека 36.6',
#   'phones': [{'phone': '+74957778899'}, {'phone': '+74957778890'}]},
#  {'activities': [{'id': 4, 'level': 1, 'name': 'Технологии', 'parent_id': None},
#                  {'id': 8,
#                   'level': 2,
#                   'name': 'Разработка ПО',
#                   'parent_id': 4}],
#   'building': {'address': '321 Elm St, North District',
#                'id': 4,
#                'latitude': 55.7538,
#                'longitude': 37.6168},
#   'building_id': 4,
#   'id': 8,
#   'name': 'Софт-Девелопмент',
#   'phones': [{'phone': '+74958889900'}, {'phone': '+74958889901'}]},
#  {'activities': [{'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None},
#                  {'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5}],
#   'building': {'address': '654 Maple Dr, South Area',
#                'id': 5,
#                'latitude': 55.7528,
#                'longitude': 37.6183},
#   'building_id': 5,
#   'id': 9,
#   'name': 'МобиШоп',
#   'phones': [{'phone': '+74959990011'}, {'phone': '+74959990012'}]},
#  {'activities': [{'id': 10, 'level': 3, 'name': 'Фастфуд', 'parent_id': 6},
#                  {'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None}],
#   'building': {'address': '654 Maple Dr, South Area',
#                'id': 5,
#                'latitude': 55.7528,
#                'longitude': 37.6183},
#   'building_id': 5,
#   'id': 10,
#   'name': 'Фастфуд "Экспресс"',
#   'phones': [{'phone': '+74950001122'}, {'phone': '+74950001123'}]},
#  {'activities': [{'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None},
#                  {'id': 11,
#                   'level': 2,
#                   'name': 'Продуктовые магазины',
#                   'parent_id': 1}],
#   'building': {'address': '987 Cedar Ln, Central',
#                'id': 6,
#                'latitude': 55.7568,
#                'longitude': 37.6153},
#   'building_id': 6,
#   'id': 11,
#   'name': 'Продукты 24/7',
#   'phones': [{'phone': '+74951113344'}, {'phone': '+74951113345'}]},
#  {'activities': [{'id': 12, 'level': 2, 'name': 'Кафе', 'parent_id': 2},
#                  {'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None}],
#   'building': {'address': '987 Cedar Ln, Central',
#                'id': 6,
#                'latitude': 55.7568,
#                'longitude': 37.6153},
#   'building_id': 6,
#   'id': 12,
#   'name': 'Кофейня "Утро"',
#   'phones': [{'phone': '+74952224455'}, {'phone': '+74952224456'}]},
#  {'activities': [{'id': 13,
#                   'level': 2,
#                   'name': 'Медицинские центры',
#                   'parent_id': 3},
#                  {'id': 3,
#                   'level': 1,
#                   'name': 'Здравоохранение',
#                   'parent_id': None}],
#   'building': {'address': '147 Birch Rd, Heights',
#                'id': 7,
#                'latitude': 55.7578,
#                'longitude': 37.6143},
#   'building_id': 7,
#   'id': 13,
#   'name': 'Клиника "Добрый доктор"',
#   'phones': [{'phone': '+74953335566'}, {'phone': '+74953335567'}]},
#  {'activities': [{'id': 14,
#                   'level': 2,
#                   'name': 'IT-консалтинг',
#                   'parent_id': 4},
#                  {'id': 4,
#                   'level': 1,
#                   'name': 'Технологии',
#                   'parent_id': None}],
#   'building': {'address': '147 Birch Rd, Heights',
#                'id': 7,
#                'latitude': 55.7578,
#                'longitude': 37.6143},
#   'building_id': 7,
#   'id': 14,
#   'name': 'ИТ-Консультант',
#   'phones': [{'phone': '+74954446677'}, {'phone': '+74954446678'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 15,
#                   'level': 3,
#                   'name': 'Бытовая техника',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '258 Spruce Ave, Valley',
#                'id': 8,
#                'latitude': 55.7588,
#                'longitude': 37.6133},
#   'building_id': 8,
#   'id': 15,
#   'name': 'Техно-Сервис',
#   'phones': [{'phone': '+74955557788'}, {'phone': '+74955557789'}]},
#  {'activities': [{'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None},
#                  {'id': 6, 'level': 2, 'name': 'Рестораны', 'parent_id': 2}],
#   'building': {'address': '258 Spruce Ave, Valley',
#                'id': 8,
#                'latitude': 55.7588,
#                'longitude': 37.6133},
#   'building_id': 8,
#   'id': 16,
#   'name': 'Ресторан "Веранда"',
#   'phones': [{'phone': '+74956668899'}, {'phone': '+74956668890'}]},
#  {'activities': [{'id': 7, 'level': 2, 'name': 'Аптеки', 'parent_id': 3},
#                  {'id': 3,
#                   'level': 1,
#                   'name': 'Здравоохранение',
#                   'parent_id': None}],
#   'building': {'address': '369 Ash St, Plaza',
#                'id': 9,
#                'latitude': 55.7598,
#                'longitude': 37.6123},
#   'building_id': 9,
#   'id': 17,
#   'name': 'Аптека "Здоровье+"',
#   'phones': [{'phone': '+74957779900'}, {'phone': '+74957779901'}]},
#  {'activities': [{'id': 4, 'level': 1, 'name': 'Технологии', 'parent_id': None},
#                  {'id': 8,
#                   'level': 2,
#                   'name': 'Разработка ПО',
#                   'parent_id': 4}],
#   'building': {'address': '369 Ash St, Plaza',
#                'id': 9,
#                'latitude': 55.7598,
#                'longitude': 37.6123},
#   'building_id': 9,
#   'id': 18,
#   'name': 'Разработка.Про',
#   'phones': [{'phone': '+74958880011'}, {'phone': '+74958880012'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '741 Willow Dr, Park',
#                'id': 10,
#                'latitude': 55.7508,
#                'longitude': 37.6193},
#   'building_id': 10,
#   'id': 19,
#   'name': 'Смартфон-Маркет',
#   'phones': [{'phone': '+74959991122'}, {'phone': '+74959991123'}]},
#  {'activities': [{'id': 10, 'level': 3, 'name': 'Фастфуд', 'parent_id': 6},
#                  {'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None}],
#   'building': {'address': '741 Willow Dr, Park',
#                'id': 10,
#                'latitude': 55.7508,
#                'longitude': 37.6193},
#   'building_id': 10,
#   'id': 20,
#   'name': 'Бургер-Хаус',
#   'phones': [{'phone': '+74950002233'}, {'phone': '+74950002234'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '123 Main St, Downtown',
#                'id': 1,
#                'latitude': 55.7558,
#                'longitude': 37.6173},
#   'building_id': 1,
#   'id': 21,
#   'name': 'Цифровой Мир',
#   'phones': [{'phone': '+74951112244'}, {'phone': '+74951112245'}]},
#  {'activities': [{'id': 12, 'level': 2, 'name': 'Кафе', 'parent_id': 2},
#                  {'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None}],
#   'building': {'address': '456 Oak Ave, West Side',
#                'id': 2,
#                'latitude': 55.7517,
#                'longitude': 37.6178},
#   'building_id': 2,
#   'id': 22,
#   'name': 'Суши-бар "Сакура"',
#   'phones': [{'phone': '+74952223355'}, {'phone': '+74952223356'}]},
#  {'activities': [{'id': 13,
#                   'level': 2,
#                   'name': 'Медицинские центры',
#                   'parent_id': 3},
#                  {'id': 3,
#                   'level': 1,
#                   'name': 'Здравоохранение',
#                   'parent_id': None}],
#   'building': {'address': '789 Pine Rd, East End',
#                'id': 3,
#                'latitude': 55.7547,
#                'longitude': 37.6163},
#   'building_id': 3,
#   'id': 23,
#   'name': 'Стоматология "Улыбка"',
#   'phones': [{'phone': '+74953334466'}, {'phone': '+74953334467'}]},
#  {'activities': [{'id': 14,
#                   'level': 2,
#                   'name': 'IT-консалтинг',
#                   'parent_id': 4},
#                  {'id': 4, 'level': 1, 'name': 'Технологии', 'parent_id': None},
#                  {'id': 8,
#                   'level': 2,
#                   'name': 'Разработка ПО',
#                   'parent_id': 4}],
#   'building': {'address': '321 Elm St, North District',
#                'id': 4,
#                'latitude': 55.7538,
#                'longitude': 37.6168},
#   'building_id': 4,
#   'id': 24,
#   'name': 'Web Studio',
#   'phones': [{'phone': '+74954445577'}, {'phone': '+74954445578'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 15,
#                   'level': 3,
#                   'name': 'Бытовая техника',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '654 Maple Dr, South Area',
#                'id': 5,
#                'latitude': 55.7528,
#                'longitude': 37.6183},
#   'building_id': 5,
#   'id': 25,
#   'name': 'Гаджет-Маркет',
#   'phones': [{'phone': '+74955556688'}, {'phone': '+74955556689'}]},
#  {'activities': [{'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None},
#                  {'id': 6, 'level': 2, 'name': 'Рестораны', 'parent_id': 2}],
#   'building': {'address': '987 Cedar Ln, Central',
#                'id': 6,
#                'latitude': 55.7568,
#                'longitude': 37.6153},
#   'building_id': 6,
#   'id': 26,
#   'name': 'Пиццерия "Италия"',
#   'phones': [{'phone': '+74956667799'}, {'phone': '+74956667800'}]},
#  {'activities': [{'id': 7, 'level': 2, 'name': 'Аптеки', 'parent_id': 3},
#                  {'id': 3,
#                   'level': 1,
#                   'name': 'Здравоохранение',
#                   'parent_id': None}],
#   'building': {'address': '147 Birch Rd, Heights',
#                'id': 7,
#                'latitude': 55.7578,
#                'longitude': 37.6143},
#   'building_id': 7,
#   'id': 27,
#   'name': 'Оптика "Взгляд"',
#   'phones': [{'phone': '+74957778800'}, {'phone': '+74957778801'}]},
#  {'activities': [{'id': 4, 'level': 1, 'name': 'Технологии', 'parent_id': None},
#                  {'id': 8,
#                   'level': 2,
#                   'name': 'Разработка ПО',
#                   'parent_id': 4}],
#   'building': {'address': '258 Spruce Ave, Valley',
#                'id': 8,
#                'latitude': 55.7588,
#                'longitude': 37.6133},
#   'building_id': 8,
#   'id': 28,
#   'name': 'Digital Agency',
#   'phones': [{'phone': '+74958889911'}, {'phone': '+74958889912'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '369 Ash St, Plaza',
#                'id': 9,
#                'latitude': 55.7598,
#                'longitude': 37.6123},
#   'building_id': 9,
#   'id': 29,
#   'name': 'Электроника-Сервис',
#   'phones': [{'phone': '+74959990022'}, {'phone': '+74959990023'}]},
#  {'activities': [{'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None},
#                  {'id': 10, 'level': 3, 'name': 'Фастфуд', 'parent_id': 6}],
#   'building': {'address': '741 Willow Dr, Park',
#                'id': 10,
#                'latitude': 55.7508,
#                'longitude': 37.6193},
#   'building_id': 10,
#   'id': 30,
#   'name': 'Столовая "Домашняя"',
#   'phones': [{'phone': '+74950001133'}, {'phone': '+74950001134'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None},
#                  {'id': 15,
#                   'level': 3,
#                   'name': 'Бытовая техника',
#                   'parent_id': 5}],
#   'building': {'address': '852 Cherry Ln, Square',
#                'id': 11,
#                'latitude': 55.7518,
#                'longitude': 37.6113},
#   'building_id': 11,
#   'id': 31,
#   'name': 'Компьютерный магазин',
#   'phones': [{'phone': '+74951113355'}, {'phone': '+74951113356'}]},
#  {'activities': [{'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None},
#                  {'id': 12, 'level': 2, 'name': 'Кафе', 'parent_id': 2}],
#   'building': {'address': '852 Cherry Ln, Square',
#                'id': 11,
#                'latitude': 55.7518,
#                'longitude': 37.6113},
#   'building_id': 11,
#   'id': 32,
#   'name': 'Чайная "Восток"',
#   'phones': [{'phone': '+74952224466'}, {'phone': '+74952224467'}]},
#  {'activities': [{'id': 13,
#                   'level': 2,
#                   'name': 'Медицинские центры',
#                   'parent_id': 3},
#                  {'id': 3,
#                   'level': 1,
#                   'name': 'Здравоохранение',
#                   'parent_id': None}],
#   'building': {'address': '963 Poplar Rd, Gardens',
#                'id': 12,
#                'latitude': 55.7528,
#                'longitude': 37.6103},
#   'building_id': 12,
#   'id': 33,
#   'name': 'Медпункт "Айболит"',
#   'phones': [{'phone': '+74953335577'}, {'phone': '+74953335578'}]},
#  {'activities': [{'id': 14,
#                   'level': 2,
#                   'name': 'IT-консалтинг',
#                   'parent_id': 4},
#                  {'id': 4, 'level': 1, 'name': 'Технологии', 'parent_id': None},
#                  {'id': 8,
#                   'level': 2,
#                   'name': 'Разработка ПО',
#                   'parent_id': 4}],
#   'building': {'address': '963 Poplar Rd, Gardens',
#                'id': 12,
#                'latitude': 55.7528,
#                'longitude': 37.6103},
#   'building_id': 12,
#   'id': 34,
#   'name': 'Software House',
#   'phones': [{'phone': '+74954446688'}, {'phone': '+74954446689'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '159 Cypress Ave, Hills',
#                'id': 13,
#                'latitude': 55.7538,
#                'longitude': 37.6093},
#   'building_id': 13,
#   'id': 35,
#   'name': 'Мир Связи',
#   'phones': [{'phone': '+74955557799'}, {'phone': '+74955557800'}]},
#  {'activities': [{'id': 12, 'level': 2, 'name': 'Кафе', 'parent_id': 2},
#                  {'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None}],
#   'building': {'address': '159 Cypress Ave, Hills',
#                'id': 13,
#                'latitude': 55.7538,
#                'longitude': 37.6093},
#   'building_id': 13,
#   'id': 36,
#   'name': 'Кафе "Прага"',
#   'phones': [{'phone': '+74956668800'}, {'phone': '+74956668801'}]},
#  {'activities': [{'id': 3,
#                   'level': 1,
#                   'name': 'Здравоохранение',
#                   'parent_id': None},
#                  {'id': 13,
#                   'level': 2,
#                   'name': 'Медицинские центры',
#                   'parent_id': 3}],
#   'building': {'address': '357 Magnolia St, Lake',
#                'id': 14,
#                'latitude': 55.7548,
#                'longitude': 37.6083},
#   'building_id': 14,
#   'id': 37,
#   'name': 'Клиника "Вита"',
#   'phones': [{'phone': '+74957779911'}, {'phone': '+74957779912'}]},
#  {'activities': [{'id': 4, 'level': 1, 'name': 'Технологии', 'parent_id': None},
#                  {'id': 8,
#                   'level': 2,
#                   'name': 'Разработка ПО',
#                   'parent_id': 4}],
#   'building': {'address': '357 Magnolia St, Lake',
#                'id': 14,
#                'latitude': 55.7548,
#                'longitude': 37.6083},
#   'building_id': 14,
#   'id': 38,
#   'name': 'Tech Support',
#   'phones': [{'phone': '+74958880022'}, {'phone': '+74958880023'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 15,
#                   'level': 3,
#                   'name': 'Бытовая техника',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '486 Juniper Dr, Ridge',
#                'id': 15,
#                'latitude': 55.7558,
#                'longitude': 37.6073},
#   'building_id': 15,
#   'id': 39,
#   'name': 'Техно-Центр',
#   'phones': [{'phone': '+74959991133'}, {'phone': '+74959991134'}]},
#  {'activities': [{'id': 6, 'level': 2, 'name': 'Рестораны', 'parent_id': 2},
#                  {'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None}],
#   'building': {'address': '486 Juniper Dr, Ridge',
#                'id': 15,
#                'latitude': 55.7558,
#                'longitude': 37.6073},
#   'building_id': 15,
#   'id': 40,
#   'name': 'Ресторан "Метрополь"',
#   'phones': [{'phone': '+74950002244'}, {'phone': '+74950002245'}]},
#  {'activities': [{'id': 7, 'level': 2, 'name': 'Аптеки', 'parent_id': 3},
#                  {'id': 3,
#                   'level': 1,
#                   'name': 'Здравоохранение',
#                   'parent_id': None}],
#   'building': {'address': '792 Sycamore Ln, View',
#                'id': 16,
#                'latitude': 55.7568,
#                'longitude': 37.6063},
#   'building_id': 16,
#   'id': 41,
#   'name': 'Аптека "Первая"',
#   'phones': [{'phone': '+74951114466'}, {'phone': '+74951114467'}]},
#  {'activities': [{'id': 4, 'level': 1, 'name': 'Технологии', 'parent_id': None},
#                  {'id': 8,
#                   'level': 2,
#                   'name': 'Разработка ПО',
#                   'parent_id': 4}],
#   'building': {'address': '792 Sycamore Ln, View',
#                'id': 16,
#                'latitude': 55.7568,
#                'longitude': 37.6063},
#   'building_id': 16,
#   'id': 42,
#   'name': 'Code Factory',
#   'phones': [{'phone': '+74952225577'}, {'phone': '+74952225578'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '148 Acacia Rd, Summit',
#                'id': 17,
#                'latitude': 55.7578,
#                'longitude': 37.6053},
#   'building_id': 17,
#   'id': 43,
#   'name': 'Смарт-Шоп',
#   'phones': [{'phone': '+74953336688'}, {'phone': '+74953336689'}]},
#  {'activities': [{'id': 10, 'level': 3, 'name': 'Фастфуд', 'parent_id': 6},
#                  {'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None}],
#   'building': {'address': '148 Acacia Rd, Summit',
#                'id': 17,
#                'latitude': 55.7578,
#                'longitude': 37.6053},
#   'building_id': 17,
#   'id': 44,
#   'name': 'Бистро "Экспресс"',
#   'phones': [{'phone': '+74954447799'}, {'phone': '+74954447800'}]},
#  {'activities': [{'id': 13,
#                   'level': 2,
#                   'name': 'Медицинские центры',
#                   'parent_id': 3},
#                  {'id': 3,
#                   'level': 1,
#                   'name': 'Здравоохранение',
#                   'parent_id': None}],
#   'building': {'address': '259 Palm Ave, Harbor',
#                'id': 18,
#                'latitude': 55.7588,
#                'longitude': 37.6043},
#   'building_id': 18,
#   'id': 45,
#   'name': 'Медцентр "Забота"',
#   'phones': [{'phone': '+74955558800'}, {'phone': '+74955558801'}]},
#  {'activities': [{'id': 14,
#                   'level': 2,
#                   'name': 'IT-консалтинг',
#                   'parent_id': 4},
#                  {'id': 4, 'level': 1, 'name': 'Технологии', 'parent_id': None},
#                  {'id': 8,
#                   'level': 2,
#                   'name': 'Разработка ПО',
#                   'parent_id': 4}],
#   'building': {'address': '259 Palm Ave, Harbor',
#                'id': 18,
#                'latitude': 55.7588,
#                'longitude': 37.6043},
#   'building_id': 18,
#   'id': 46,
#   'name': 'DevOps Labs',
#   'phones': [{'phone': '+74956669911'}, {'phone': '+74956669912'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 15,
#                   'level': 3,
#                   'name': 'Бытовая техника',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '367 Redwood St, Beach',
#                'id': 19,
#                'latitude': 55.7598,
#                'longitude': 37.6033},
#   'building_id': 19,
#   'id': 47,
#   'name': 'Электро-Мир',
#   'phones': [{'phone': '+74957770022'}, {'phone': '+74957770023'}]},
#  {'activities': [{'id': 12, 'level': 2, 'name': 'Кафе', 'parent_id': 2},
#                  {'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None}],
#   'building': {'address': '367 Redwood St, Beach',
#                'id': 19,
#                'latitude': 55.7598,
#                'longitude': 37.6033},
#   'building_id': 19,
#   'id': 48,
#   'name': 'Кафе "Венеция"',
#   'phones': [{'phone': '+74958881133'}, {'phone': '+74958881134'}]}]

# %% [markdown]
# ## 3. Работа со зданиями

# %%
# Получение списка зданий
response = requests.get(f"{BASE_URL}/buildings", headers=headers)
print(f"Список всех зданий:")
pprint(response.json())
# Out:
# Список всех зданий:
# [{'address': '123 Main St, Downtown',
#   'id': 1,
#   'latitude': 55.7558,
#   'longitude': 37.6173},
#  {'address': '456 Oak Ave, West Side',
#   'id': 2,
#   'latitude': 55.7517,
#   'longitude': 37.6178},
#  {'address': '789 Pine Rd, East End',
#   'id': 3,
#   'latitude': 55.7547,
#   'longitude': 37.6163},
#  {'address': '321 Elm St, North District',
#   'id': 4,
#   'latitude': 55.7538,
#   'longitude': 37.6168},
#  {'address': '654 Maple Dr, South Area',
#   'id': 5,
#   'latitude': 55.7528,
#   'longitude': 37.6183},
#  {'address': '987 Cedar Ln, Central',
#   'id': 6,
#   'latitude': 55.7568,
#   'longitude': 37.6153},
#  {'address': '147 Birch Rd, Heights',
#   'id': 7,
#   'latitude': 55.7578,
#   'longitude': 37.6143},
#  {'address': '258 Spruce Ave, Valley',
#   'id': 8,
#   'latitude': 55.7588,
#   'longitude': 37.6133},
#  {'address': '369 Ash St, Plaza',
#   'id': 9,
#   'latitude': 55.7598,
#   'longitude': 37.6123},
#  {'address': '741 Willow Dr, Park',
#   'id': 10,
#   'latitude': 55.7508,
#   'longitude': 37.6193},
#  {'address': '852 Cherry Ln, Square',
#   'id': 11,
#   'latitude': 55.7518,
#   'longitude': 37.6113},
#  {'address': '963 Poplar Rd, Gardens',
#   'id': 12,
#   'latitude': 55.7528,
#   'longitude': 37.6103},
#  {'address': '159 Cypress Ave, Hills',
#   'id': 13,
#   'latitude': 55.7538,
#   'longitude': 37.6093},
#  {'address': '357 Magnolia St, Lake',
#   'id': 14,
#   'latitude': 55.7548,
#   'longitude': 37.6083},
#  {'address': '486 Juniper Dr, Ridge',
#   'id': 15,
#   'latitude': 55.7558,
#   'longitude': 37.6073},
#  {'address': '792 Sycamore Ln, View',
#   'id': 16,
#   'latitude': 55.7568,
#   'longitude': 37.6063},
#  {'address': '148 Acacia Rd, Summit',
#   'id': 17,
#   'latitude': 55.7578,
#   'longitude': 37.6053},
#  {'address': '259 Palm Ave, Harbor',
#   'id': 18,
#   'latitude': 55.7588,
#   'longitude': 37.6043},
#  {'address': '367 Redwood St, Beach',
#   'id': 19,
#   'latitude': 55.7598,
#   'longitude': 37.6033},
#  {'address': '481 Sequoia Dr, Forest',
#   'id': 20,
#   'latitude': 55.7508,
#   'longitude': 37.6023}]

# %%
# Получение конкретного здания
building_id = 1
response = requests.get(f"{BASE_URL}/buildings/{building_id}", headers=headers)
print(f"Информация о здании {building_id}:")
pprint(response.json())
# Out:
# Информация о здании 1:
# {'address': '123 Main St, Downtown',
#  'id': 1,
#  'latitude': 55.7558,
#  'longitude': 37.6173}

# %%
# Получение списка организаций в здании
building_id = 1
response = requests.get(f"{BASE_URL}/buildings/{building_id}/organizations", headers=headers)
print(f"Организации в здании {building_id}:")
pprint(response.json())
# Out:
# Организации в здании 1:
# [{'activities': [{'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None},
#                  {'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1}],
#   'building': {'address': '123 Main St, Downtown',
#                'id': 1,
#                'latitude': 55.7558,
#                'longitude': 37.6173},
#   'building_id': 1,
#   'id': 1,
#   'name': 'ТехноМаркет',
#   'phones': [{'phone': '+74951112233'}, {'phone': '+74951112234'}]},
#  {'activities': [{'id': 12, 'level': 2, 'name': 'Кафе', 'parent_id': 2},
#                  {'id': 2,
#                   'level': 1,
#                   'name': 'Общественное питание',
#                   'parent_id': None}],
#   'building': {'address': '123 Main St, Downtown',
#                'id': 1,
#                'latitude': 55.7558,
#                'longitude': 37.6173},
#   'building_id': 1,
#   'id': 2,
#   'name': 'Кафе "У Парка"',
#   'phones': [{'phone': '+74952223344'}, {'phone': '+74952223345'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '123 Main St, Downtown',
#                'id': 1,
#                'latitude': 55.7558,
#                'longitude': 37.6173},
#   'building_id': 1,
#   'id': 21,
#   'name': 'Цифровой Мир',
#   'phones': [{'phone': '+74951112244'}, {'phone': '+74951112245'}]}]

# %% [markdown]
# ## 4. Работа с видами деятельности

# %%
# Получение дерева видов деятельности
response = requests.get(f"{BASE_URL}/activities", headers=headers)
print(f"Дерево видов деятельности:")
pprint(response.json())
# Out:
# Дерево видов деятельности:
# [{'children': [{'children': [{'children': [],
#                               'id': 9,
#                               'level': 3,
#                               'name': 'Мобильные телефоны',
#                               'parent_id': 5},
#                              {'children': [],
#                               'id': 15,
#                               'level': 3,
#                               'name': 'Бытовая техника',
#                               'parent_id': 5}],
#                 'id': 5,
#                 'level': 2,
#                 'name': 'Электроника',
#                 'parent_id': 1},
#                {'children': [],
#                 'id': 11,
#                 'level': 2,
#                 'name': 'Продуктовые магазины',
#                 'parent_id': 1}],
#   'id': 1,
#   'level': 1,
#   'name': 'Розничная торговля',
#   'parent_id': None},
#  {'children': [{'children': [{'children': [],
#                               'id': 10,
#                               'level': 3,
#                               'name': 'Фастфуд',
#                               'parent_id': 6}],
#                 'id': 6,
#                 'level': 2,
#                 'name': 'Рестораны',
#                 'parent_id': 2},
#                {'children': [],
#                 'id': 12,
#                 'level': 2,
#                 'name': 'Кафе',
#                 'parent_id': 2}],
#   'id': 2,
#   'level': 1,
#   'name': 'Общественное питание',
#   'parent_id': None},
#  {'children': [{'children': [],
#                 'id': 7,
#                 'level': 2,
#                 'name': 'Аптеки',
#                 'parent_id': 3},
#                {'children': [],
#                 'id': 13,
#                 'level': 2,
#                 'name': 'Медицинские центры',
#                 'parent_id': 3}],
#   'id': 3,
#   'level': 1,
#   'name': 'Здравоохранение',
#   'parent_id': None},
#  {'children': [{'children': [],
#                 'id': 8,
#                 'level': 2,
#                 'name': 'Разработка ПО',
#                 'parent_id': 4},
#                {'children': [],
#                 'id': 14,
#                 'level': 2,
#                 'name': 'IT-консалтинг',
#                 'parent_id': 4}],
#   'id': 4,
#   'level': 1,
#   'name': 'Технологии',
#   'parent_id': None}]

# %%
# Поиск организаций по виду деятельности
params = {"activity_id": 1}
response = requests.get(f"{BASE_URL}/organizations", headers=headers, params=params)
print(f"Организации с видом деятельности 1:")
pprint(response.json())
# Out:
# Организации с видом деятельности 1:
# [{'activities': [{'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '123 Main St, Downtown',
#                'id': 1,
#                'latitude': 55.7558,
#                'longitude': 37.6173},
#   'building_id': 1,
#   'id': 1,
#   'name': 'ТехноМаркет',
#   'phones': [{'id': 1, 'organization_id': 1, 'phone': '+74951112233'},
#              {'id': 2, 'organization_id': 1, 'phone': '+74951112234'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 15,
#                   'level': 3,
#                   'name': 'Бытовая техника',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '789 Pine Rd, East End',
#                'id': 3,
#                'latitude': 55.7547,
#                'longitude': 37.6163},
#   'building_id': 3,
#   'id': 5,
#   'name': 'Электроника и К',
#   'phones': [{'id': 9, 'organization_id': 5, 'phone': '+74955556677'},
#              {'id': 10, 'organization_id': 5, 'phone': '+74955556678'}]},
#  {'activities': [{'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '654 Maple Dr, South Area',
#                'id': 5,
#                'latitude': 55.7528,
#                'longitude': 37.6183},
#   'building_id': 5,
#   'id': 9,
#   'name': 'МобиШоп',
#   'phones': [{'id': 17, 'organization_id': 9, 'phone': '+74959990011'},
#              {'id': 18, 'organization_id': 9, 'phone': '+74959990012'}]},
#  {'activities': [{'id': 11,
#                   'level': 2,
#                   'name': 'Продуктовые магазины',
#                   'parent_id': 1},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '987 Cedar Ln, Central',
#                'id': 6,
#                'latitude': 55.7568,
#                'longitude': 37.6153},
#   'building_id': 6,
#   'id': 11,
#   'name': 'Продукты 24/7',
#   'phones': [{'id': 21, 'organization_id': 11, 'phone': '+74951113344'},
#              {'id': 22, 'organization_id': 11, 'phone': '+74951113345'}]},
#  {'activities': [{'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None},
#                  {'id': 15,
#                   'level': 3,
#                   'name': 'Бытовая техника',
#                   'parent_id': 5},
#                  {'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1}],
#   'building': {'address': '258 Spruce Ave, Valley',
#                'id': 8,
#                'latitude': 55.7588,
#                'longitude': 37.6133},
#   'building_id': 8,
#   'id': 15,
#   'name': 'Техно-Сервис',
#   'phones': [{'id': 29, 'organization_id': 15, 'phone': '+74955557788'},
#              {'id': 30, 'organization_id': 15, 'phone': '+74955557789'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '741 Willow Dr, Park',
#                'id': 10,
#                'latitude': 55.7508,
#                'longitude': 37.6193},
#   'building_id': 10,
#   'id': 19,
#   'name': 'Смартфон-Маркет',
#   'phones': [{'id': 37, 'organization_id': 19, 'phone': '+74959991122'},
#              {'id': 38, 'organization_id': 19, 'phone': '+74959991123'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '123 Main St, Downtown',
#                'id': 1,
#                'latitude': 55.7558,
#                'longitude': 37.6173},
#   'building_id': 1,
#   'id': 21,
#   'name': 'Цифровой Мир',
#   'phones': [{'id': 41, 'organization_id': 21, 'phone': '+74951112244'},
#              {'id': 42, 'organization_id': 21, 'phone': '+74951112245'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 15,
#                   'level': 3,
#                   'name': 'Бытовая техника',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '654 Maple Dr, South Area',
#                'id': 5,
#                'latitude': 55.7528,
#                'longitude': 37.6183},
#   'building_id': 5,
#   'id': 25,
#   'name': 'Гаджет-Маркет',
#   'phones': [{'id': 49, 'organization_id': 25, 'phone': '+74955556688'},
#              {'id': 50, 'organization_id': 25, 'phone': '+74955556689'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '369 Ash St, Plaza',
#                'id': 9,
#                'latitude': 55.7598,
#                'longitude': 37.6123},
#   'building_id': 9,
#   'id': 29,
#   'name': 'Электроника-Сервис',
#   'phones': [{'id': 57, 'organization_id': 29, 'phone': '+74959990022'},
#              {'id': 58, 'organization_id': 29, 'phone': '+74959990023'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 15,
#                   'level': 3,
#                   'name': 'Бытовая техника',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '852 Cherry Ln, Square',
#                'id': 11,
#                'latitude': 55.7518,
#                'longitude': 37.6113},
#   'building_id': 11,
#   'id': 31,
#   'name': 'Компьютерный магазин',
#   'phones': [{'id': 61, 'organization_id': 31, 'phone': '+74951113355'},
#              {'id': 62, 'organization_id': 31, 'phone': '+74951113356'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '159 Cypress Ave, Hills',
#                'id': 13,
#                'latitude': 55.7538,
#                'longitude': 37.6093},
#   'building_id': 13,
#   'id': 35,
#   'name': 'Мир Связи',
#   'phones': [{'id': 69, 'organization_id': 35, 'phone': '+74955557799'},
#              {'id': 70, 'organization_id': 35, 'phone': '+74955557800'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 15,
#                   'level': 3,
#                   'name': 'Бытовая техника',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '486 Juniper Dr, Ridge',
#                'id': 15,
#                'latitude': 55.7558,
#                'longitude': 37.6073},
#   'building_id': 15,
#   'id': 39,
#   'name': 'Техно-Центр',
#   'phones': [{'id': 77, 'organization_id': 39, 'phone': '+74959991133'},
#              {'id': 78, 'organization_id': 39, 'phone': '+74959991134'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '148 Acacia Rd, Summit',
#                'id': 17,
#                'latitude': 55.7578,
#                'longitude': 37.6053},
#   'building_id': 17,
#   'id': 43,
#   'name': 'Смарт-Шоп',
#   'phones': [{'id': 85, 'organization_id': 43, 'phone': '+74953336688'},
#              {'id': 86, 'organization_id': 43, 'phone': '+74953336689'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 15,
#                   'level': 3,
#                   'name': 'Бытовая техника',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '367 Redwood St, Beach',
#                'id': 19,
#                'latitude': 55.7598,
#                'longitude': 37.6033},
#   'building_id': 19,
#   'id': 47,
#   'name': 'Электро-Мир',
#   'phones': [{'id': 93, 'organization_id': 47, 'phone': '+74957770022'},
#              {'id': 94, 'organization_id': 47, 'phone': '+74957770023'}]}]

# %% [markdown]
# ## 5. Комбинированные запросы

# %%
# Поиск организаций по виду деятельности в радиусе
params = {
    "activity_id": 1,
    "lat": 55.7558,
    "lon": 37.6173,
    "radius": 1.0
}
response = requests.get(f"{BASE_URL}/organizations", headers=headers, params=params)
print(f"Организации с видом деятельности 1 в радиусе 1 км:")
pprint(response.json())
# Out:
# Организации с видом деятельности 1 в радиусе 1 км:
# [{'activities': [{'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '123 Main St, Downtown',
#                'id': 1,
#                'latitude': 55.7558,
#                'longitude': 37.6173},
#   'building_id': 1,
#   'id': 1,
#   'name': 'ТехноМаркет',
#   'phones': [{'id': 1, 'organization_id': 1, 'phone': '+74951112233'},
#              {'id': 2, 'organization_id': 1, 'phone': '+74951112234'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 15,
#                   'level': 3,
#                   'name': 'Бытовая техника',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '789 Pine Rd, East End',
#                'id': 3,
#                'latitude': 55.7547,
#                'longitude': 37.6163},
#   'building_id': 3,
#   'id': 5,
#   'name': 'Электроника и К',
#   'phones': [{'id': 9, 'organization_id': 5, 'phone': '+74955556677'},
#              {'id': 10, 'organization_id': 5, 'phone': '+74955556678'}]},
#  {'activities': [{'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '654 Maple Dr, South Area',
#                'id': 5,
#                'latitude': 55.7528,
#                'longitude': 37.6183},
#   'building_id': 5,
#   'id': 9,
#   'name': 'МобиШоп',
#   'phones': [{'id': 17, 'organization_id': 9, 'phone': '+74959990011'},
#              {'id': 18, 'organization_id': 9, 'phone': '+74959990012'}]},
#  {'activities': [{'id': 11,
#                   'level': 2,
#                   'name': 'Продуктовые магазины',
#                   'parent_id': 1},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '987 Cedar Ln, Central',
#                'id': 6,
#                'latitude': 55.7568,
#                'longitude': 37.6153},
#   'building_id': 6,
#   'id': 11,
#   'name': 'Продукты 24/7',
#   'phones': [{'id': 21, 'organization_id': 11, 'phone': '+74951113344'},
#              {'id': 22, 'organization_id': 11, 'phone': '+74951113345'}]},
#  {'activities': [{'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None},
#                  {'id': 15,
#                   'level': 3,
#                   'name': 'Бытовая техника',
#                   'parent_id': 5},
#                  {'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1}],
#   'building': {'address': '258 Spruce Ave, Valley',
#                'id': 8,
#                'latitude': 55.7588,
#                'longitude': 37.6133},
#   'building_id': 8,
#   'id': 15,
#   'name': 'Техно-Сервис',
#   'phones': [{'id': 29, 'organization_id': 15, 'phone': '+74955557788'},
#              {'id': 30, 'organization_id': 15, 'phone': '+74955557789'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '741 Willow Dr, Park',
#                'id': 10,
#                'latitude': 55.7508,
#                'longitude': 37.6193},
#   'building_id': 10,
#   'id': 19,
#   'name': 'Смартфон-Маркет',
#   'phones': [{'id': 37, 'organization_id': 19, 'phone': '+74959991122'},
#              {'id': 38, 'organization_id': 19, 'phone': '+74959991123'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '123 Main St, Downtown',
#                'id': 1,
#                'latitude': 55.7558,
#                'longitude': 37.6173},
#   'building_id': 1,
#   'id': 21,
#   'name': 'Цифровой Мир',
#   'phones': [{'id': 41, 'organization_id': 21, 'phone': '+74951112244'},
#              {'id': 42, 'organization_id': 21, 'phone': '+74951112245'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 15,
#                   'level': 3,
#                   'name': 'Бытовая техника',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '654 Maple Dr, South Area',
#                'id': 5,
#                'latitude': 55.7528,
#                'longitude': 37.6183},
#   'building_id': 5,
#   'id': 25,
#   'name': 'Гаджет-Маркет',
#   'phones': [{'id': 49, 'organization_id': 25, 'phone': '+74955556688'},
#              {'id': 50, 'organization_id': 25, 'phone': '+74955556689'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '369 Ash St, Plaza',
#                'id': 9,
#                'latitude': 55.7598,
#                'longitude': 37.6123},
#   'building_id': 9,
#   'id': 29,
#   'name': 'Электроника-Сервис',
#   'phones': [{'id': 57, 'organization_id': 29, 'phone': '+74959990022'},
#              {'id': 58, 'organization_id': 29, 'phone': '+74959990023'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 15,
#                   'level': 3,
#                   'name': 'Бытовая техника',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '852 Cherry Ln, Square',
#                'id': 11,
#                'latitude': 55.7518,
#                'longitude': 37.6113},
#   'building_id': 11,
#   'id': 31,
#   'name': 'Компьютерный магазин',
#   'phones': [{'id': 61, 'organization_id': 31, 'phone': '+74951113355'},
#              {'id': 62, 'organization_id': 31, 'phone': '+74951113356'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '159 Cypress Ave, Hills',
#                'id': 13,
#                'latitude': 55.7538,
#                'longitude': 37.6093},
#   'building_id': 13,
#   'id': 35,
#   'name': 'Мир Связи',
#   'phones': [{'id': 69, 'organization_id': 35, 'phone': '+74955557799'},
#              {'id': 70, 'organization_id': 35, 'phone': '+74955557800'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 15,
#                   'level': 3,
#                   'name': 'Бытовая техника',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '486 Juniper Dr, Ridge',
#                'id': 15,
#                'latitude': 55.7558,
#                'longitude': 37.6073},
#   'building_id': 15,
#   'id': 39,
#   'name': 'Техно-Центр',
#   'phones': [{'id': 77, 'organization_id': 39, 'phone': '+74959991133'},
#              {'id': 78, 'organization_id': 39, 'phone': '+74959991134'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 9,
#                   'level': 3,
#                   'name': 'Мобильные телефоны',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '148 Acacia Rd, Summit',
#                'id': 17,
#                'latitude': 55.7578,
#                'longitude': 37.6053},
#   'building_id': 17,
#   'id': 43,
#   'name': 'Смарт-Шоп',
#   'phones': [{'id': 85, 'organization_id': 43, 'phone': '+74953336688'},
#              {'id': 86, 'organization_id': 43, 'phone': '+74953336689'}]},
#  {'activities': [{'id': 5, 'level': 2, 'name': 'Электроника', 'parent_id': 1},
#                  {'id': 15,
#                   'level': 3,
#                   'name': 'Бытовая техника',
#                   'parent_id': 5},
#                  {'id': 1,
#                   'level': 1,
#                   'name': 'Розничная торговля',
#                   'parent_id': None}],
#   'building': {'address': '367 Redwood St, Beach',
#                'id': 19,
#                'latitude': 55.7598,
#                'longitude': 37.6033},
#   'building_id': 19,
#   'id': 47,
#   'name': 'Электро-Мир',
#   'phones': [{'id': 93, 'organization_id': 47, 'phone': '+74957770022'},
#              {'id': 94, 'organization_id': 47, 'phone': '+74957770023'}]}]
